# %% [markdown]
# ## Variable length sequence LSTM full script
#
# In this script, the whole process of loading data, training and testing the LSTM is written.
# The script is as generalized as it can get, since the variables of the model change based on the underlying dataset.
# This has been done to allow for the addition of new actions and data without having to change the code.
# Since it is a variable length sequence LSTM, ragged tensors are used.
# The predicting logic is a fixed length LSTM with 8 frame length. Being it real-time, it is not possible to predict variable length sequence, since one does not now when the sequence is completed. A challenge will be finding the sweet spot in terms of sequence length (for now it is 8 frames).

# %%
#importing needed libraries

import numpy as np
import tensorflow as tf
import cv2
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, InputLayer
from tensorflow.keras.callbacks import TensorBoard

# %%
#setting up the mediapipe model

mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

#defining a few functions to detect, draw and extract keypoints

def mediapipe_detection(image, model):
    #this function takes in the image and the model and returns the prediction results
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

def draw_landmarks(image, results, drawing_spec_circle, drawing_spec_line):
    #this function takes in the image and results and draws mediapipe landmarks on the picture
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, landmark_drawing_spec=drawing_spec_circle, connection_drawing_spec=drawing_spec_line)
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, landmark_drawing_spec=drawing_spec_circle, connection_drawing_spec=drawing_spec_line)
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, landmark_drawing_spec=drawing_spec_circle, connection_drawing_spec=drawing_spec_line)
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, landmark_drawing_spec=drawing_spec_circle, connection_drawing_spec=drawing_spec_line)

def extract_keypoints(results):
    #this function takes in the prediction results and returns the array with the extracted keypoints to be saved
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

def visualize_probabilities(res, actions, input_frame, colors):
    #this function takes in the action probabilities and actions, and draws the coloured probability rectangles on the picture
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*200), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    return output_frame

# %%
#preparing the action categories and paths

actions = []

DATA_PATH = os.path.join(os.getcwd(), "DATA")

for action in os.listdir(DATA_PATH):
    actions.append(action)
    
actions = np.array(actions)

label_map = {label:num for num, label in enumerate(actions)}

labels, temp_points = [], []

# %%
#a temporary solution to the initializing ragged tensors problem is to initialize with a standard value and then deleting it at
#the end. I didn't find any better solution since documentation on ragged tensors is not so clean
temporary_ragged = tf.ragged.constant([[[3, 1, 4, 1], [5, 9, 2], [6], []]], tf.double)

#for every action, loops and loads data for training
for action in actions: 
    for num_sequence in os.listdir(os.path.join(DATA_PATH, action)):
        temp_points = []
        for point in os.listdir(os.path.join(DATA_PATH, action, num_sequence)):
            res = np.load(os.path.join(DATA_PATH, action, num_sequence, point), allow_pickle = True)
            temp_points.append(res)       
            
        temporary_ragged = tf.concat([temporary_ragged, tf.expand_dims(np.array(temp_points), axis = 0)], axis = 0)
        labels.append(label_map[action])

#skips the first tensor, that is the one we used to intialize the variable
dataset = temporary_ragged[1:]

# %%
#preparing train and test sets (not really the cleanest way, ragged tensors don't seem too friendly to handle).
#In the future I should add data augmentation as well, but it will probably be not clean to do that with ragged tensors

y = to_categorical(labels).astype(int)
train_ind = int(dataset.shape[0]*0.9)
X_train = dataset[:train_ind]
X_test = dataset[train_ind:]
y_train = y[:train_ind]
y_test = y[train_ind:]
print(y.shape)
# Out:
# (889, 5)

# %%
#initializing the Keras model. Different models have been tested, for now with the dataset we have this has performed the best
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=[None, 1662], ragged=True),
    tf.keras.layers.LSTM(64, activation = 'tanh', dropout=0.2, return_sequences = True),
    tf.keras.layers.LSTM(128, activation = 'tanh', dropout=0.2, return_sequences = True),
    tf.keras.layers.LSTM(64, activation = 'tanh', dropout=0.2),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation = 'relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation = 'relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(len(actions), activation = 'softmax'),
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19360\240508149.py in <module>
#       2 model = tf.keras.Sequential([
#       3     tf.keras.layers.InputLayer(input_shape=[None, 1662], ragged=True),
# ----> 4     tf.keras.layers.experimental.preprocessing.RandomFlip(mode='HORIZONTAL_AND_VERTICAL'),
#       5     tf.keras.layers.LSTM(64, activation = 'tanh', dropout=0.2, return_sequences = True),
#       6     tf.keras.layers.LSTM(128, activation = 'tanh', dropout=0.2, return_sequences = True),
#
# ~\anaconda3\envs\mediapipe1\lib\site-packages\tensorflow\python\keras\layers\preprocessing\image_preprocessing.py in __init__(self, mode, seed, **kwargs)
#     401     else:
#     402       raise ValueError('RandomFlip layer {name} received an unknown mode '
# --> 403                        'argument {arg}'.format(name=self.name, arg=mode))
#     404     self.seed = seed
#     405     self._rng = make_generator(self.seed)
#
# ValueError: RandomFlip layer random_flip_1 received an unknown mode argument HORIZONTAL_AND_VERTICAL

# %%
#defining compiler and callback to stop training and 97% accuracy
model.compile(optimizer = 'Adam', loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])

ACCURACY_THRESHOLD = 0.97

class myCallback(tf.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('categorical_accuracy') > ACCURACY_THRESHOLD):   
            print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))   
            self.model.stop_training = True

# %%
callb = myCallback()

#training the model
model.fit(X_train, y_train, epochs = 4000, callbacks = callb)
# Out:
# Epoch 1/4000
# 25/25 [==============================] - 15s 288ms/step - loss: 1.5697 - categorical_accuracy: 0.2450
# Epoch 2/4000
# 25/25 [==============================] - 7s 279ms/step - loss: 1.4995 - categorical_accuracy: 0.3150
# Epoch 3/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 1.4626 - categorical_accuracy: 0.3200
# Epoch 4/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 1.4084 - categorical_accuracy: 0.3100
# Epoch 5/4000
# 25/25 [==============================] - 7s 283ms/step - loss: 1.4049 - categorical_accuracy: 0.3262
# Epoch 6/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 1.3717 - categorical_accuracy: 0.3438
# Epoch 7/4000
# 25/25 [==============================] - 7s 281ms/step - loss: 1.3783 - categorical_accuracy: 0.3100
# Epoch 8/4000
# 25/25 [==============================] - 7s 268ms/step - loss: 1.3359 - categorical_accuracy: 0.3400
# Epoch 9/4000
# 25/25 [==============================] - 6s 254ms/step - loss: 1.3123 - categorical_accuracy: 0.3650
# Epoch 10/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 1.2812 - categorical_accuracy: 0.4175
# Epoch 11/4000
# 25/25 [==============================] - 7s 263ms/step - loss: 1.2584 - categorical_accuracy: 0.4313
# Epoch 12/4000
# 25/25 [==============================] - 6s 256ms/step - loss: 1.2158 - categorical_accuracy: 0.4775
# Epoch 13/4000
# 25/25 [==============================] - 7s 275ms/step - loss: 1.1363 - categorical_accuracy: 0.5000
# Epoch 14/4000
# 25/25 [==============================] - 7s 250ms/step - loss: 1.1592 - categorical_accuracy: 0.4938
# Epoch 15/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 1.1035 - categorical_accuracy: 0.5188
# Epoch 16/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 1.0608 - categorical_accuracy: 0.5537
# Epoch 17/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 1.0690 - categorical_accuracy: 0.5038
# Epoch 18/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 1.0210 - categorical_accuracy: 0.5512
# Epoch 19/4000
# 25/25 [==============================] - 6s 256ms/step - loss: 0.9986 - categorical_accuracy: 0.5838
# Epoch 20/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.9554 - categorical_accuracy: 0.5788
# Epoch 21/4000
# 25/25 [==============================] - 7s 275ms/step - loss: 0.9098 - categorical_accuracy: 0.5975
# Epoch 22/4000
# 25/25 [==============================] - 7s 246ms/step - loss: 0.9111 - categorical_accuracy: 0.6050
# Epoch 23/4000
# 25/25 [==============================] - 6s 245ms/step - loss: 0.8946 - categorical_accuracy: 0.6325
# Epoch 24/4000
# 25/25 [==============================] - 7s 284ms/step - loss: 0.8901 - categorical_accuracy: 0.6300
# Epoch 25/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.7978 - categorical_accuracy: 0.6925
# Epoch 26/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 0.7612 - categorical_accuracy: 0.6963
# Epoch 27/4000
# 25/25 [==============================] - 6s 255ms/step - loss: 0.7815 - categorical_accuracy: 0.7088
# Epoch 28/4000
# 25/25 [==============================] - 6s 258ms/step - loss: 0.8162 - categorical_accuracy: 0.6488
# Epoch 29/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.7210 - categorical_accuracy: 0.7088
# Epoch 30/4000
# 25/25 [==============================] - 7s 279ms/step - loss: 0.6872 - categorical_accuracy: 0.7400
# Epoch 31/4000
# 25/25 [==============================] - 7s 281ms/step - loss: 0.8873 - categorical_accuracy: 0.6250
# Epoch 32/4000
# 25/25 [==============================] - 7s 273ms/step - loss: 0.7168 - categorical_accuracy: 0.7237
# Epoch 33/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.7139 - categorical_accuracy: 0.7437
# Epoch 34/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.6403 - categorical_accuracy: 0.7688
# Epoch 35/4000
# 25/25 [==============================] - 6s 257ms/step - loss: 0.6431 - categorical_accuracy: 0.7862
# Epoch 36/4000
# 25/25 [==============================] - 7s 273ms/step - loss: 0.6802 - categorical_accuracy: 0.7613
# Epoch 37/4000
# 25/25 [==============================] - 6s 249ms/step - loss: 0.6527 - categorical_accuracy: 0.7475
# Epoch 38/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.7808 - categorical_accuracy: 0.7138
# Epoch 39/4000
# 25/25 [==============================] - 6s 232ms/step - loss: 0.6194 - categorical_accuracy: 0.7613
# Epoch 40/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.6949 - categorical_accuracy: 0.7287
# Epoch 41/4000
# 25/25 [==============================] - 6s 258ms/step - loss: 0.5528 - categorical_accuracy: 0.7825
# Epoch 42/4000
# 25/25 [==============================] - 7s 261ms/step - loss: 0.5155 - categorical_accuracy: 0.8375
# Epoch 43/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.5259 - categorical_accuracy: 0.8375
# Epoch 44/4000
# 25/25 [==============================] - 7s 290ms/step - loss: 0.6465 - categorical_accuracy: 0.7750
# Epoch 45/4000
# 25/25 [==============================] - 7s 263ms/step - loss: 0.6283 - categorical_accuracy: 0.7812
# Epoch 46/4000
# 25/25 [==============================] - 6s 260ms/step - loss: 0.5077 - categorical_accuracy: 0.8263
# Epoch 47/4000
# 25/25 [==============================] - 7s 263ms/step - loss: 0.4770 - categorical_accuracy: 0.8475
# Epoch 48/4000
# 25/25 [==============================] - 7s 288ms/step - loss: 0.4923 - categorical_accuracy: 0.8450
# Epoch 49/4000
# 25/25 [==============================] - 6s 263ms/step - loss: 0.4802 - categorical_accuracy: 0.8650
# Epoch 50/4000
# 25/25 [==============================] - 6s 260ms/step - loss: 0.4951 - categorical_accuracy: 0.8313
# Epoch 51/4000
# 25/25 [==============================] - 6s 257ms/step - loss: 0.4588 - categorical_accuracy: 0.8438
# Epoch 52/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.4754 - categorical_accuracy: 0.8662
# Epoch 53/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.3936 - categorical_accuracy: 0.8813
# Epoch 54/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 0.3988 - categorical_accuracy: 0.8737
# Epoch 55/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 0.4487 - categorical_accuracy: 0.8562
# Epoch 56/4000
# 25/25 [==============================] - 7s 275ms/step - loss: 0.4490 - categorical_accuracy: 0.8725
# Epoch 57/4000
# 25/25 [==============================] - 7s 290ms/step - loss: 0.4027 - categorical_accuracy: 0.8788
# Epoch 58/4000
# 25/25 [==============================] - 7s 289ms/step - loss: 0.3910 - categorical_accuracy: 0.8750
# Epoch 59/4000
# 25/25 [==============================] - 7s 279ms/step - loss: 0.4272 - categorical_accuracy: 0.8662
# Epoch 60/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.3948 - categorical_accuracy: 0.8662
# Epoch 61/4000
# 25/25 [==============================] - 7s 256ms/step - loss: 0.3377 - categorical_accuracy: 0.8888
# Epoch 62/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.3822 - categorical_accuracy: 0.8788
# Epoch 63/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 0.4095 - categorical_accuracy: 0.8725
# Epoch 64/4000
# 25/25 [==============================] - 6s 256ms/step - loss: 0.3462 - categorical_accuracy: 0.8925
# Epoch 65/4000
# 25/25 [==============================] - 7s 285ms/step - loss: 0.3618 - categorical_accuracy: 0.8838
# Epoch 66/4000
# 25/25 [==============================] - 7s 279ms/step - loss: 0.3625 - categorical_accuracy: 0.8850
# Epoch 67/4000
# 25/25 [==============================] - 6s 260ms/step - loss: 0.3257 - categorical_accuracy: 0.8950
# Epoch 68/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.3274 - categorical_accuracy: 0.8925
# Epoch 69/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.5325 - categorical_accuracy: 0.8450
# Epoch 70/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.3580 - categorical_accuracy: 0.8737
# Epoch 71/4000
# 25/25 [==============================] - 6s 249ms/step - loss: 0.3594 - categorical_accuracy: 0.8775
# Epoch 72/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.3633 - categorical_accuracy: 0.8775
# Epoch 73/4000
# 25/25 [==============================] - 7s 284ms/step - loss: 0.3047 - categorical_accuracy: 0.9050
# Epoch 74/4000
# 25/25 [==============================] - 6s 259ms/step - loss: 0.4267 - categorical_accuracy: 0.8550
# Epoch 75/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.3884 - categorical_accuracy: 0.8788
# Epoch 76/4000
# 25/25 [==============================] - 7s 287ms/step - loss: 0.3243 - categorical_accuracy: 0.8925
# Epoch 77/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.3152 - categorical_accuracy: 0.8975
# Epoch 78/4000
# 25/25 [==============================] - 7s 262ms/step - loss: 0.3190 - categorical_accuracy: 0.8963
# Epoch 79/4000
# 25/25 [==============================] - 7s 273ms/step - loss: 0.2962 - categorical_accuracy: 0.9000
# Epoch 80/4000
# 25/25 [==============================] - 7s 263ms/step - loss: 0.3199 - categorical_accuracy: 0.8875
# Epoch 81/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.2925 - categorical_accuracy: 0.8975
# Epoch 82/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.3202 - categorical_accuracy: 0.8950
# Epoch 83/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 0.2796 - categorical_accuracy: 0.9000
# Epoch 84/4000
# 25/25 [==============================] - 7s 284ms/step - loss: 0.2583 - categorical_accuracy: 0.9075
# Epoch 85/4000
# 25/25 [==============================] - 7s 283ms/step - loss: 0.2806 - categorical_accuracy: 0.9125
# Epoch 86/4000
# 25/25 [==============================] - 7s 286ms/step - loss: 0.2704 - categorical_accuracy: 0.9000
# Epoch 87/4000
# 25/25 [==============================] - 7s 290ms/step - loss: 0.2683 - categorical_accuracy: 0.8988
# Epoch 88/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.2708 - categorical_accuracy: 0.9162
# Epoch 89/4000
# 25/25 [==============================] - 7s 272ms/step - loss: 0.3707 - categorical_accuracy: 0.8700
# Epoch 90/4000
# 25/25 [==============================] - 7s 266ms/step - loss: 0.3417 - categorical_accuracy: 0.8825
# Epoch 91/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.3700 - categorical_accuracy: 0.8825
# Epoch 92/4000
# 25/25 [==============================] - 7s 281ms/step - loss: 0.3203 - categorical_accuracy: 0.8913
# Epoch 93/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 0.2824 - categorical_accuracy: 0.9013
# Epoch 94/4000
# 25/25 [==============================] - 7s 266ms/step - loss: 0.4312 - categorical_accuracy: 0.8575
# Epoch 95/4000
# 25/25 [==============================] - 7s 286ms/step - loss: 0.4268 - categorical_accuracy: 0.8575
# Epoch 96/4000
# 25/25 [==============================] - 6s 257ms/step - loss: 0.2852 - categorical_accuracy: 0.9050
# Epoch 97/4000
# 25/25 [==============================] - 7s 245ms/step - loss: 0.3082 - categorical_accuracy: 0.9038
# Epoch 98/4000
# 25/25 [==============================] - 7s 272ms/step - loss: 0.2850 - categorical_accuracy: 0.9112
# Epoch 99/4000
# 25/25 [==============================] - 6s 262ms/step - loss: 0.3808 - categorical_accuracy: 0.8888
# Epoch 100/4000
# 25/25 [==============================] - 7s 273ms/step - loss: 0.3217 - categorical_accuracy: 0.8963
# Epoch 101/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.2880 - categorical_accuracy: 0.9125
# Epoch 102/4000
# 25/25 [==============================] - 7s 288ms/step - loss: 0.2725 - categorical_accuracy: 0.9150
# Epoch 103/4000
# 25/25 [==============================] - 7s 285ms/step - loss: 0.2808 - categorical_accuracy: 0.9200
# Epoch 104/4000
# 25/25 [==============================] - 7s 300ms/step - loss: 0.2992 - categorical_accuracy: 0.9075
# Epoch 105/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.3497 - categorical_accuracy: 0.8838
# Epoch 106/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 0.2543 - categorical_accuracy: 0.9212
# Epoch 107/4000
# 25/25 [==============================] - 7s 272ms/step - loss: 0.2529 - categorical_accuracy: 0.9250
# Epoch 108/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 0.2150 - categorical_accuracy: 0.9312
# Epoch 109/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 0.2153 - categorical_accuracy: 0.9225
# Epoch 110/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 0.2158 - categorical_accuracy: 0.9337
# Epoch 111/4000
# 25/25 [==============================] - 7s 290ms/step - loss: 0.2276 - categorical_accuracy: 0.9275
# Epoch 112/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.2246 - categorical_accuracy: 0.9250
# Epoch 113/4000
# 25/25 [==============================] - 7s 245ms/step - loss: 0.3668 - categorical_accuracy: 0.8838
# Epoch 114/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 0.2979 - categorical_accuracy: 0.8888
# Epoch 115/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 0.2999 - categorical_accuracy: 0.9125
# Epoch 116/4000
# 25/25 [==============================] - 6s 255ms/step - loss: 0.3230 - categorical_accuracy: 0.8913
# Epoch 117/4000
# 25/25 [==============================] - 6s 253ms/step - loss: 0.2778 - categorical_accuracy: 0.9112
# Epoch 118/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.2492 - categorical_accuracy: 0.9162
# Epoch 119/4000
# 25/25 [==============================] - 7s 250ms/step - loss: 0.2474 - categorical_accuracy: 0.9262
# Epoch 120/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 0.2143 - categorical_accuracy: 0.9162
# Epoch 121/4000
# 25/25 [==============================] - 6s 257ms/step - loss: 0.2312 - categorical_accuracy: 0.9250
# Epoch 122/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.2803 - categorical_accuracy: 0.9150
# Epoch 123/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.2334 - categorical_accuracy: 0.9350
# Epoch 124/4000
# 25/25 [==============================] - 6s 253ms/step - loss: 0.2014 - categorical_accuracy: 0.9388
# Epoch 125/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 0.2063 - categorical_accuracy: 0.9300
# Epoch 126/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.1951 - categorical_accuracy: 0.9375
# Epoch 127/4000
# 25/25 [==============================] - 7s 257ms/step - loss: 0.1850 - categorical_accuracy: 0.9287
# Epoch 128/4000
# 25/25 [==============================] - 6s 254ms/step - loss: 0.2400 - categorical_accuracy: 0.9175
# Epoch 129/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.1987 - categorical_accuracy: 0.9400
# Epoch 130/4000
# 25/25 [==============================] - 7s 259ms/step - loss: 0.2823 - categorical_accuracy: 0.9175
# Epoch 131/4000
# 25/25 [==============================] - 6s 247ms/step - loss: 0.2578 - categorical_accuracy: 0.9125
# Epoch 132/4000
# 25/25 [==============================] - 6s 262ms/step - loss: 0.2304 - categorical_accuracy: 0.9075
# Epoch 133/4000
# 25/25 [==============================] - 7s 249ms/step - loss: 0.2014 - categorical_accuracy: 0.9287
# Epoch 134/4000
# 25/25 [==============================] - 6s 256ms/step - loss: 0.2195 - categorical_accuracy: 0.9250
# Epoch 135/4000
# 25/25 [==============================] - 7s 292ms/step - loss: 0.2172 - categorical_accuracy: 0.9200
# Epoch 136/4000
# 25/25 [==============================] - 7s 282ms/step - loss: 0.1991 - categorical_accuracy: 0.9312
# Epoch 137/4000
# 25/25 [==============================] - 6s 246ms/step - loss: 0.2485 - categorical_accuracy: 0.9150
# Epoch 138/4000
# 25/25 [==============================] - 7s 283ms/step - loss: 0.2855 - categorical_accuracy: 0.9100
# Epoch 139/4000
# 25/25 [==============================] - 6s 246ms/step - loss: 0.3311 - categorical_accuracy: 0.9112
# Epoch 140/4000
# 25/25 [==============================] - 7s 268ms/step - loss: 0.4566 - categorical_accuracy: 0.8512
# Epoch 141/4000
# 25/25 [==============================] - 6s 247ms/step - loss: 0.3154 - categorical_accuracy: 0.9087
# Epoch 142/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.2455 - categorical_accuracy: 0.9175
# Epoch 143/4000
# 25/25 [==============================] - 6s 257ms/step - loss: 0.2140 - categorical_accuracy: 0.9362
# Epoch 144/4000
# 25/25 [==============================] - 7s 272ms/step - loss: 0.2097 - categorical_accuracy: 0.9300
# Epoch 145/4000
# 25/25 [==============================] - 7s 257ms/step - loss: 0.1935 - categorical_accuracy: 0.9350
# Epoch 146/4000
# 25/25 [==============================] - 7s 286ms/step - loss: 0.2002 - categorical_accuracy: 0.9400
# Epoch 147/4000
# 25/25 [==============================] - 7s 267ms/step - loss: 0.2940 - categorical_accuracy: 0.9100
# Epoch 148/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 0.2740 - categorical_accuracy: 0.9162
# Epoch 149/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.2197 - categorical_accuracy: 0.9325
# Epoch 150/4000
# 25/25 [==============================] - 7s 282ms/step - loss: 0.2326 - categorical_accuracy: 0.9162
# Epoch 151/4000
# 25/25 [==============================] - 7s 275ms/step - loss: 0.1841 - categorical_accuracy: 0.9425
# Epoch 152/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 0.1508 - categorical_accuracy: 0.9475
# Epoch 153/4000
# 25/25 [==============================] - 7s 269ms/step - loss: 0.1824 - categorical_accuracy: 0.9400
# Epoch 154/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.1776 - categorical_accuracy: 0.9413
# Epoch 155/4000
# 25/25 [==============================] - 7s 291ms/step - loss: 0.3516 - categorical_accuracy: 0.9137
# Epoch 156/4000
# 25/25 [==============================] - 7s 267ms/step - loss: 0.5656 - categorical_accuracy: 0.8012
# Epoch 157/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 0.2957 - categorical_accuracy: 0.9237
# Epoch 158/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.2214 - categorical_accuracy: 0.9237
# Epoch 159/4000
# 25/25 [==============================] - 7s 267ms/step - loss: 0.2075 - categorical_accuracy: 0.9337
# Epoch 160/4000
# 25/25 [==============================] - 7s 284ms/step - loss: 0.2000 - categorical_accuracy: 0.9388
# Epoch 161/4000
# 25/25 [==============================] - 7s 267ms/step - loss: 0.1974 - categorical_accuracy: 0.9337
# Epoch 162/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 0.1813 - categorical_accuracy: 0.9350
# Epoch 163/4000
# 25/25 [==============================] - 7s 283ms/step - loss: 0.1907 - categorical_accuracy: 0.9312
# Epoch 164/4000
# 25/25 [==============================] - 6s 260ms/step - loss: 0.2028 - categorical_accuracy: 0.9325
# Epoch 165/4000
# 25/25 [==============================] - 7s 263ms/step - loss: 0.1898 - categorical_accuracy: 0.9362
# Epoch 166/4000
# 25/25 [==============================] - 7s 277ms/step - loss: 0.1681 - categorical_accuracy: 0.9463
# Epoch 167/4000
# 25/25 [==============================] - 7s 289ms/step - loss: 0.2150 - categorical_accuracy: 0.9350
# Epoch 168/4000
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1687 - categorical_accuracy: 0.9425
# Epoch 169/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 0.2407 - categorical_accuracy: 0.9312
# Epoch 170/4000
# 25/25 [==============================] - 7s 281ms/step - loss: 0.2215 - categorical_accuracy: 0.9350
# Epoch 171/4000
# 25/25 [==============================] - 7s 281ms/step - loss: 0.2038 - categorical_accuracy: 0.9337
# Epoch 172/4000
# 25/25 [==============================] - 7s 247ms/step - loss: 0.1672 - categorical_accuracy: 0.9413
# Epoch 173/4000
# 25/25 [==============================] - 7s 289ms/step - loss: 0.1539 - categorical_accuracy: 0.9500
# Epoch 174/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 0.1268 - categorical_accuracy: 0.9588
# Epoch 175/4000
# 25/25 [==============================] - 7s 273ms/step - loss: 0.2233 - categorical_accuracy: 0.9337
# Epoch 176/4000
# 25/25 [==============================] - 7s 287ms/step - loss: 0.2121 - categorical_accuracy: 0.9312
# Epoch 177/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 0.4232 - categorical_accuracy: 0.8813
# Epoch 178/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 0.2342 - categorical_accuracy: 0.9388
# Epoch 179/4000
# 25/25 [==============================] - 7s 267ms/step - loss: 0.2145 - categorical_accuracy: 0.9350
# Epoch 180/4000
# 25/25 [==============================] - 7s 264ms/step - loss: 0.1780 - categorical_accuracy: 0.9463
# Epoch 181/4000
# 25/25 [==============================] - 7s 264ms/step - loss: 0.1709 - categorical_accuracy: 0.9475
# Epoch 182/4000
# 25/25 [==============================] - 7s 263ms/step - loss: 0.1296 - categorical_accuracy: 0.9500
# Epoch 183/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.1335 - categorical_accuracy: 0.9525
# Epoch 184/4000
# 25/25 [==============================] - 7s 261ms/step - loss: 0.1864 - categorical_accuracy: 0.9425
# Epoch 185/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 0.1456 - categorical_accuracy: 0.9438
# Epoch 186/4000
# 25/25 [==============================] - 7s 267ms/step - loss: 0.1415 - categorical_accuracy: 0.9525
# Epoch 187/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.1416 - categorical_accuracy: 0.9500
# Epoch 188/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 0.2713 - categorical_accuracy: 0.9187
# Epoch 189/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 0.2633 - categorical_accuracy: 0.9175
# Epoch 190/4000
# 25/25 [==============================] - 7s 281ms/step - loss: 0.2070 - categorical_accuracy: 0.9237
# Epoch 191/4000
# 25/25 [==============================] - 7s 262ms/step - loss: 0.1594 - categorical_accuracy: 0.9475
# Epoch 192/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.1300 - categorical_accuracy: 0.9513
# Epoch 193/4000
# 25/25 [==============================] - 7s 251ms/step - loss: 0.1410 - categorical_accuracy: 0.9500
# Epoch 194/4000
# 25/25 [==============================] - 7s 267ms/step - loss: 0.1281 - categorical_accuracy: 0.9500
# Epoch 195/4000
# 25/25 [==============================] - 7s 246ms/step - loss: 0.2722 - categorical_accuracy: 0.9250
# Epoch 196/4000
# 25/25 [==============================] - 7s 262ms/step - loss: 0.2159 - categorical_accuracy: 0.9312
# Epoch 197/4000
# 25/25 [==============================] - 7s 262ms/step - loss: 0.1543 - categorical_accuracy: 0.9538
# Epoch 198/4000
# 25/25 [==============================] - 7s 284ms/step - loss: 0.1369 - categorical_accuracy: 0.9538
# Epoch 199/4000
# 25/25 [==============================] - 7s 276ms/step - loss: 0.2234 - categorical_accuracy: 0.9337
# Epoch 200/4000
# 25/25 [==============================] - 7s 278ms/step - loss: 0.2751 - categorical_accuracy: 0.8900
# Epoch 201/4000
# 25/25 [==============================] - 7s 292ms/step - loss: 0.2067 - categorical_accuracy: 0.9175
# Epoch 202/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 0.1630 - categorical_accuracy: 0.9400
# Epoch 203/4000
# 25/25 [==============================] - 7s 268ms/step - loss: 0.1918 - categorical_accuracy: 0.9250
# Epoch 204/4000
# 25/25 [==============================] - 7s 279ms/step - loss: 0.1391 - categorical_accuracy: 0.9488
# Epoch 205/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 0.1625 - categorical_accuracy: 0.9362
# Epoch 206/4000
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1929 - categorical_accuracy: 0.9450
# Epoch 207/4000
# 25/25 [==============================] - 7s 268ms/step - loss: 0.2174 - categorical_accuracy: 0.9425
# Epoch 208/4000
# 25/25 [==============================] - 7s 290ms/step - loss: 0.2359 - categorical_accuracy: 0.9400
# Epoch 209/4000
# 25/25 [==============================] - 7s 272ms/step - loss: 0.1366 - categorical_accuracy: 0.9600
# Epoch 210/4000
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1487 - categorical_accuracy: 0.9588
# Epoch 211/4000
# 25/25 [==============================] - 7s 275ms/step - loss: 0.1398 - categorical_accuracy: 0.9500
# Epoch 212/4000
# 25/25 [==============================] - 7s 274ms/step - loss: 0.1357 - categorical_accuracy: 0.9575
# Epoch 213/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 0.1460 - categorical_accuracy: 0.9538
# Epoch 214/4000
# 25/25 [==============================] - 7s 279ms/step - loss: 0.1082 - categorical_accuracy: 0.9638
# Epoch 215/4000
# 25/25 [==============================] - 6s 241ms/step - loss: 0.1196 - categorical_accuracy: 0.9600
# Epoch 216/4000
# 25/25 [==============================] - 7s 279ms/step - loss: 0.1146 - categorical_accuracy: 0.9625
# Epoch 217/4000
# 25/25 [==============================] - 7s 279ms/step - loss: 0.1086 - categorical_accuracy: 0.9638
# Epoch 218/4000
# 25/25 [==============================] - 7s 268ms/step - loss: 0.1334 - categorical_accuracy: 0.9500
# Epoch 219/4000
# 25/25 [==============================] - 7s 285ms/step - loss: 0.8047 - categorical_accuracy: 0.7825
# Epoch 220/4000
# 25/25 [==============================] - 7s 271ms/step - loss: 0.3600 - categorical_accuracy: 0.8825
# Epoch 221/4000
# 25/25 [==============================] - 7s 284ms/step - loss: 0.2061 - categorical_accuracy: 0.9350
# Epoch 222/4000
# 25/25 [==============================] - 7s 264ms/step - loss: 0.1698 - categorical_accuracy: 0.9400
# Epoch 223/4000
# 25/25 [==============================] - 7s 264ms/step - loss: 0.1482 - categorical_accuracy: 0.9513
# Epoch 224/4000
# 25/25 [==============================] - 7s 283ms/step - loss: 0.1481 - categorical_accuracy: 0.9463
# Epoch 225/4000
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1511 - categorical_accuracy: 0.9475
# Epoch 226/4000
# 25/25 [==============================] - 7s 258ms/step - loss: 0.1458 - categorical_accuracy: 0.9488
# Epoch 227/4000
# 25/25 [==============================] - 7s 280ms/step - loss: 0.1715 - categorical_accuracy: 0.9350
# Epoch 228/4000
# 25/25 [==============================] - 7s 255ms/step - loss: 0.2625 - categorical_accuracy: 0.9187
# Epoch 229/4000
# 25/25 [==============================] - 7s 281ms/step - loss: 0.2827 - categorical_accuracy: 0.9125
# Epoch 230/4000
# 25/25 [==============================] - 7s 270ms/step - loss: 0.1716 - categorical_accuracy: 0.9388
# Epoch 231/4000
# 25/25 [==============================] - 7s 289ms/step - loss: 0.1367 - categorical_accuracy: 0.9563
# Epoch 232/4000
# 25/25 [==============================] - 7s 275ms/step - loss: 0.1551 - categorical_accuracy: 0.9450
# Epoch 233/4000
# 25/25 [==============================] - 7s 259ms/step - loss: 0.2376 - categorical_accuracy: 0.9325
# Epoch 234/4000
# 25/25 [==============================] - 7s 265ms/step - loss: 0.1308 - categorical_accuracy: 0.9613
# Epoch 235/4000
# 25/25 [==============================] - 6s 243ms/step - loss: 0.1052 - categorical_accuracy: 0.9700
#
# Reached 97.00% accuracy, so stopping training!!

# %%
#using confusion matrix to determine how well the model performs on the test set (false positive and negatives)
yhat = model.predict(X_test)
ytrue = np.argmax(y_test, axis = 1).tolist()
yhat = np.argmax(yhat, axis = 1).tolist()
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[86,  3],
#         [ 0,  0]],
#
#        [[71, 18],
#         [ 0,  0]],
#
#        [[87,  2],
#         [ 0,  0]],
#
#        [[ 0,  0],
#         [23, 66]]], dtype=int64)

# %%
#printing out the accuracy
accuracy_score(ytrue, yhat)
# Out:
# 0.7415730337078652

# %%
#saving the weights
model.save('model_weights\\5_actions_741(to_test).h5')

# %%
#loading the weights of a previously saved model
model.load_weights('model_weights\\5_actions_741(to_test).h5')

# %%
#testing in real-time

colors = [(0,0,0), (255,255,255), (0,255,0), (255,0,0), (0,0,255)]
sequence = []
sentence = []
predictions = [0]
threshold = 0.95

#choosing the camera to use
cap = cv2.VideoCapture(0)

#drawing specs for face dots
drawing_spec_circle = mp_drawing.DrawingSpec()
drawing_spec_circle.circle_radius = 1
drawing_spec_circle.thickness = 1
drawing_spec_circle.color = (0,0,255)

prev_frame_time = 0
new_frame_time = 0

#drawing specs for face connections
drawing_spec_line = mp_drawing.DrawingSpec()
drawing_spec_line.thickness = 1

#starting the loop
with mp_holistic.Holistic(min_detection_confidence=0.8) as holistic:
    while cap.isOpened():

        ret,frame = cap.read()

        #make detections
        image, results = mediapipe_detection(frame, holistic)
        
        #count and show fps
        new_frame_time = time.time()
        fps = 1/(new_frame_time-prev_frame_time)
        prev_frame_time = new_frame_time
        fps = int(fps)
        fps = str(fps)
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(image, fps, (550, 120), font, 3, (100, 255, 0), 3, cv2.LINE_AA)
        
        #drawing landmarks
        draw_landmarks(image, results, drawing_spec_circle, drawing_spec_line)
        
        #extracting keypoints and feeding them to the LSTM for prediction
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-10:]
        
        if len(sequence) == 10:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            image = visualize_probabilities(res, actions, image, colors)
        
        #this would be the rendering logic if one would want to write the action. The first line implies that the action gets
        #written only if predicted for 10 consecutive frames, to give an higher stability to the model. This logic is not used
        #now, if one would like to implement that, just add 2 lines of code to display a text box with the sentence in
            if np.unique(predictions[-10:])[0] == np.argmax(res):
                if res[np.argmax(res)] > threshold:
                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])    

            if len(sentence) > 5:
                sentence = sentence[-5:]

        #showing image with predictions
        cv2.imshow('the feed', image)

        #close loop
        if cv2.waitKey(10) & 0XFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# hand_bite
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# head_scratch
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# cover_face
# no_action
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# no_action
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# no_action
# no_action
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# cover_ears
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
# no_action
